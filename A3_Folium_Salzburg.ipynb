# %% [markdown]
# # **Rest Areas and Museums in Salzburg Using Folium**

# %% [markdown]
# Using the Folium library, which enables the production of interactive web maps, I hope to investigate and display Salzburg's geospatial data in this assignment. I use the OSMnx library to extract and filter useful OpenStreetMap (OSM) data, such as rest areas and museums. This investigation aids in locating important landmarks and scenic elements important to urban outdoor and cultural events. Additionally, it will help my final project, which is about optimising routes and visualising them on web-based maps.

# %%
import folium

# %%
# !pip install osmnx
# Out:
# Requirement already satisfied: osmnx in /usr/local/lib/python3.11/dist-packages (2.0.3)
# Requirement already satisfied: geopandas>=1.0 in /usr/local/lib/python3.11/dist-packages (from osmnx) (1.0.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from osmnx) (3.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.32.3)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.1.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0->osmnx) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0->osmnx) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0->osmnx) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)

# %%
import osmnx as ox

# %%
print("OSMnx version:", ox.__version__)
# Out:
# OSMnx version: 2.0.3

# %%
# Define Salzburg coordinates
salzburg_coords = [47.8095, 13.0550]

# %%
# Create a base map
salzburg_map = folium.Map(location=salzburg_coords, tiles="cartodb positron", zoom_start=13)

# -----------------------------
# Museums (tourism = museum)
# -----------------------------

# %%
tags_museums = {'tourism': 'museum'}
museums = ox.features_from_place('Salzburg, Austria', tags=tags_museums)

# %%
for idx, row in museums.iterrows():
    if row.geometry.geom_type == 'Point':
        name = row.get('name', 'Museum')
        folium.Marker(
            location=[row.geometry.y, row.geometry.x],
            popup=name,
            icon=folium.Icon(color='purple', icon='university', prefix='fa')
        ).add_to(salzburg_map)

# %%
# -----------------------------
# Rest Areas (amenity = bench or leisure = picnic_table)
# -----------------------------
tags_rest = {'amenity': 'bench', 'leisure': 'picnic_table'}
rest_areas = ox.features_from_place('Salzburg, Austria', tags=tags_rest)

# %%
for idx, row in rest_areas.iterrows():
    if row.geometry.geom_type == 'Point':
        name = row.get('name', 'Rest Area')
        folium.Marker(
            location=[row.geometry.y, row.geometry.x],
            popup=name,
            icon=folium.Icon(color='green', icon='bed', prefix='fa')
        ).add_to(salzburg_map)

# %%
# Add layer control
folium.LayerControl().add_to(salzburg_map)

# %%
# Show the map
salzburg_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e4002d3d55ef2781145503a812ed15f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e4002d3d55ef2781145503a812ed15f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e4002d3d55ef2781145503a812ed15f = L.map(
#                 &quot;map_4e4002d3d55ef2781145503a812ed15f&quot;,
#                 {
#                     center: [47.8095, 13.055],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dda1896086cc9fd6b8f020c09cbacdb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1dda1896086cc9fd6b8f020c09cbacdb.addTo(map_4e4002d3d55ef2781145503a812ed15f);
#
#
#             var marker_f8cf7419e4ea459ec7d16a2b0dae2fc3 = L.marker(
#                 [47.8026506, 13.0437708],
#                 {
# }
#             ).addTo(map_4e4002d3d55ef2781145503a812ed15f);
#
#
#             var icon_29b54a1d2bb19f65b144ab2cb82feec8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;university&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8b2950fd5c0d69dead237b97e65a7a88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e9e37e18aa1b54f7d9986c5d03275f2 = $(`&lt;div id=&quot;html_0e9e37e18aa1b54f7d9986c5d03275f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mozart Wohnhaus&lt;/div&gt;`)[0];
#                 popup_8b2950fd5c0d69dead237b97e65a7a88.setContent(html_0e9e37e18aa1b54f7d9986c5d03275f2);
#
#
#
#         marker_f8cf7419e4ea459ec7d16a2b0dae2fc3.bindPopup(popup_8b2950fd5c0d69dead237b97e65a7a88)
#         ;
#
#
#
#
#                 marker_f8cf7419e4ea459ec7d16a2b0dae2fc3.setIcon(icon_29b54a1d2bb19f65b144ab2cb82feec8);
#
#
#             var marker_888c81ad9ba081967315ae72a3652bc5 = L.marker(
#                 [47.7996438, 13.0399208],
#                 {
# }
#             ).addTo(map_4e4002d3d55ef2781145503a812ed15f);
#
#
#             var icon_3abcdbacc4212197efe47e8328085310 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;university&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a2d09661e2a2cf28227062298b5f3587 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09d249101589e07833ddd62277b24a1d = $(`&lt;div id=&quot;html_09d249101589e07833ddd62277b24a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Spielzeugmuseum&lt;/div&gt;`)[0];
#                 popup_a2d09661e2a2cf28227062298b5f3587.setContent(html_09d249101589e07833ddd62277b24a1d);
#
#
#
#         marker_888c81ad9ba081967315ae72a3652bc5.bindPopup(popup_a2d09661e2a2cf28227062298b5f3587)
#         ;
#
#
#
#
#                 marker_888c81ad9ba081967315ae72a3652bc5.setIcon(icon_3abcdbacc4212197efe47e8328085310);
#
#
#             var marker_d9650f38d77a2b194562a64ffe834b79 = L.marker(
#                 [47.7979648, 13.0475616],
#                 {
# }
#             ).addTo(map_4e4002d3d55ef2781145503a812ed15f);
#
#
#             var icon_0400c1ad028670fc24dee5b277ed9711 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;university&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3b06244f1410a8c5dae2e2fa13aca72b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4823f8f73eddddca4a1c3b441133f059 = $(`&lt;div id=&quot;html_4823f8f73eddddca4a1c3b441133f059&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Panorama Museum&lt;/div&gt;`)[0];
#                 popup_3b06244f1410a8c5dae2e2fa13aca72b.setContent(html_4823f8f73eddddca4a1c3b441133f059);
#
#
#
#         marker_d9650f38d77a2b194562a64ffe834b79.bindPopup(popup_3b06244f1410a8c5dae2e2fa13aca72b)
#         ;
#
#
#
#
#                 marker_d9650f38d77a2b194562a64ffe834b79.set

# %% [markdown]
# ### Libraries Used
#
# - Folium: A powerful Python library for interactive map visualizations using Leaflet.js.
#   Documentation: [https://python-visualization.github.io/folium/](https://python-visualization.github.io/folium/)
#
# - OSMnx: A library to download and analyze street networks and geospatial features from OpenStreetMap.
#   Documentation: [https://osmnx.readthedocs.io/](https://osmnx.readthedocs.io/)
